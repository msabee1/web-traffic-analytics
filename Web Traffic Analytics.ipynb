# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data-export (1).csv")

# %%
df.head()
# Out:
#           # ----------------------------------------  \
# 0  Session primary channel group (Default channel...
# 1                                             Direct
# 2                                     Organic Social
# 3                                             Direct
# 4                                     Organic Social
#
#                  Unnamed: 1 Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0  Date + hour (YYYYMMDDHH)      Users   Sessions  Engaged sessions
# 1                2024041623        237        300               144
# 2                2024041719        208        267               132
# 3                2024041723        188        233               115
# 4                2024041718        187        256               125
#
#                             Unnamed: 5                 Unnamed: 6  \
# 0  Average engagement time per session  Engaged sessions per user
# 1                   47.526666666666700         0.6075949367088610
# 2                    32.09737827715360         0.6346153846153850
# 3                    39.93991416309010         0.6117021276595740
# 4                          32.16015625         0.6684491978609630
#
#            Unnamed: 7           Unnamed: 8   Unnamed: 9
# 0  Events per session      Engagement rate  Event count
# 1   4.673333333333330                 0.48         1402
# 2   4.295880149812730   0.4943820224719100         1147
# 3   4.587982832618030  0.49356223175965700         1069
# 4            4.078125           0.48828125         1044

# %%
df.columns = df.iloc[0]
df = df.drop(index = 0).reset_index(drop = True)
df.columns = ["channel group", "DateHour", "Users", "Sessions", "Engaged Sessions", "Average engagement time per session", "Engaged sessions per user", "Events per session", "Engagement rate", "Event count"]

# %%
df.head()
# Out:
#     channel group    DateHour Users Sessions Engaged Sessions  \
# 0  Organic Social  2024041718   187      256              125
# 1  Organic Social  2024041720   175      221              112
# 2  Organic Social  2024041721   160      206              103
# 3  Organic Social  2024050119   160      219              110
# 4          Direct  2024041622   158      192               94
#
#   Average engagement time per session Engaged sessions per user  \
# 0                         32.16015625        0.6684491978609630
# 1                  46.918552036199100                      0.64
# 2                   59.31553398058250                   0.64375
# 3                   40.31506849315070                    0.6875
# 4                  39.020833333333300        0.5949367088607590
#
#   Events per session     Engagement rate Event count
# 0           4.078125          0.48828125        1044
# 1  4.529411764705880  0.5067873303167420        1001
# 2  4.694174757281550                 0.5         967
# 3   4.63013698630137   0.502283105022831        1014
# 4  4.057291666666670  0.4895833333333330         779

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3179 entries, 0 to 3178
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   channel group                        3179 non-null   object
#  1   DateHour                             3179 non-null   object
#  2   Users                                3179 non-null   object
#  3   Sessions                             3179 non-null   object
#  4   Engaged Sessions                     3179 non-null   object
#  5   Average engagement time per session  3179 non-null   object
#  6   Engaged sessions per user            3179 non-null   object
#  7   Events per session                   3179 non-null   object
#  8   Engagement rate                      3179 non-null   object
#  9   Event count                          3179 non-null   object
# dtypes: object(10)
# memory usage: 248.5+ KB

# %%
df["DateHour"] = pd.to_datetime(df["DateHour"], format="%Y%m%d%H", errors='coerce')

# %%
numeric_cols = df.columns.drop(["channel group", "DateHour"])
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')
df["Hour"] = df["DateHour"].dt.hour

# %%
df.head()
# Out:
#     channel group            DateHour  Users  Sessions  Engaged Sessions  \
# 0  Organic Social 2024-04-17 18:00:00    187       256               125
# 1  Organic Social 2024-04-17 20:00:00    175       221               112
# 2  Organic Social 2024-04-17 21:00:00    160       206               103
# 3  Organic Social 2024-05-01 19:00:00    160       219               110
# 4          Direct 2024-04-16 22:00:00    158       192                94
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            32.160156                   0.668449
# 1                            46.918552                   0.640000
# 2                            59.315534                   0.643750
# 3                            40.315068                   0.687500
# 4                            39.020833                   0.594937
#
#    Events per session  Engagement rate  Event count  Hour
# 0            4.078125         0.488281         1044    18
# 1            4.529412         0.506787         1001    20
# 2            4.694175         0.500000          967    21
# 3            4.630137         0.502283         1014    19
# 4            4.057292         0.489583          779    22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3179 entries, 0 to 3178
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   channel group                        3179 non-null   object
#  1   DateHour                             3179 non-null   datetime64[ns]
#  2   Users                                3179 non-null   int64
#  3   Sessions                             3179 non-null   int64
#  4   Engaged Sessions                     3179 non-null   int64
#  5   Average engagement time per session  3179 non-null   float64
#  6   Engaged sessions per user            3179 non-null   float64
#  7   Events per session                   3179 non-null   float64
#  8   Engagement rate                      3179 non-null   float64
#  9   Event count                          3179 non-null   int64
#  10  Hour                                 3179 non-null   int32
# dtypes: datetime64[ns](1), float64(4), int32(1), int64(4), object(1)
# memory usage: 260.9+ KB

# %%
df.describe()
# Out:
#                             DateHour        Users     Sessions  \
# count                           3179  3179.000000  3179.000000
# mean   2024-04-20 01:20:29.820698368    41.776345    50.989305
# min              2024-04-06 00:00:00     0.000000     1.000000
# 25%              2024-04-13 02:00:00    20.000000    24.000000
# 50%              2024-04-20 03:00:00    42.000000    51.000000
# 75%              2024-04-26 22:00:00    60.000000    71.000000
# max              2024-05-03 23:00:00   187.000000   256.000000
# std                              NaN    29.129828    36.328970
#
#        Engaged Sessions  Average engagement time per session  \
# count       3179.000000                          3179.000000
# mean          28.229317                            66.669863
# min            0.000000                             0.000000
# 25%           13.000000                            32.091250
# 50%           27.000000                            49.096154
# 75%           41.000000                            71.518519
# max          125.000000                          4525.000000
# std           20.417710                           127.257871
#
#        Engaged sessions per user  Events per session  Engagement rate  \
# count                3179.000000         3179.000000      3179.000000
# mean                    0.606439            4.676117         0.503410
# min                     0.000000            1.000000         0.000000
# 25%                     0.561404            3.750000         0.442857
# 50%                     0.666667            4.410256         0.545455
# 75%                     0.750000            5.218981         0.633333
# max                     2.000000           56.000000         1.000000
# std                     0.264147            2.796538         0.228313
#
#        Event count         Hour
# count  3179.000000  3179.000000
# mean    241.363007    11.797735
# min       1.000000     0.000000
# 25%     103.000000     6.000000
# 50%     226.000000    12.000000
# 75%     339.000000    18.000000
# max    1117.000000    23.000000
# std     182.081506     6.883023

# %% [markdown]
# # sessions and users overtime

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(10,5))
df.groupby("DateHour")[["Sessions","Users"]].sum().plot(ax=plt.gca())
plt.title("Sessions and users over time")
plt.xlabel("DateHour")
plt.ylabel("count")
plt.show()

# %% [markdown]
# # total users by channel

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x="channel group", y="Users", estimator=np.sum, palette="viridis")
plt.title("Total Users by Channel")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\mohds\AppData\Local\Temp\ipykernel_11368\2084067767.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="channel group", y="Users", estimator=np.sum, palette="viridis")

# %% [markdown]
# # average engagement time

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x="channel group", y="Average engagement time per session", estimator =np.mean, palette = "magma")
plt.title("Avg Engagement Time by Channel")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\mohds\AppData\Local\Temp\ipykernel_11368\3899330355.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="channel group", y="Average engagement time per session", estimator =np.mean, palette = "magma")

# %% [markdown]
# # Engagement Rate Distribution by channel

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x="channel group", y="Engagement rate", palette="coolwarm")
plt.title(" Engagement Rate Distribution by Channel")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\mohds\AppData\Local\Temp\ipykernel_11368\919773368.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="channel group", y="Engagement rate", palette="coolwarm")

# %% [markdown]
# # Engaged vs non engaged sessions

# %%
session_df = df.groupby("channel group")[["Sessions", "Engaged Sessions"]].sum().reset_index()
session_df["Non-Engaged"] = session_df["Sessions"] - session_df["Engaged Sessions"]
session_df_melted = session_df.melt(id_vars="channel group", value_vars=["Engaged Sessions", "Non-Engaged"])
plt.figure(figsize=(8, 5))
sns.barplot(data=session_df_melted, x="channel group", y="value", hue="variable")
plt.title("Engaged vs Non-Engaged Sessions")
plt.xticks(rotation=45)
plt.show()

# %%
df.head()
# Out:
#     channel group    DateHour Users Sessions Engaged Sessions  \
# 0  Organic Social  2024041718   187      256              125
# 1  Organic Social  2024041720   175      221              112
# 2  Organic Social  2024041721   160      206              103
# 3  Organic Social  2024050119   160      219              110
# 4          Direct  2024041622   158      192               94
#
#   Average engagement time per session Engaged sessions per user  \
# 0                         32.16015625        0.6684491978609630
# 1                  46.918552036199100                      0.64
# 2                   59.31553398058250                   0.64375
# 3                   40.31506849315070                    0.6875
# 4                  39.020833333333300        0.5949367088607590
#
#   Events per session     Engagement rate Event count
# 0           4.078125          0.48828125        1044
# 1  4.529411764705880  0.5067873303167420        1001
# 2  4.694174757281550                 0.5         967
# 3   4.63013698630137   0.502283105022831        1014
# 4  4.057291666666670  0.4895833333333330         779

# %% [markdown]
# # traffic by hour and channel

# %%
heatmap_data = df.groupby(["Hour", "channel group"])["Sessions"].sum().unstack()
plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, cmap="YlGnBu", linewidths=.5, annot=True, fmt='.0f')
plt.title("Traffic by Hour and Channel")
plt.xlabel("Channel Group")
plt.ylabel("Hour of Day")
plt.show()

# %% [markdown]
# # engagement rate vs sessions over time

# %%
df.head()
# Out:
#     channel group            DateHour  Users  Sessions  Engaged Sessions  \
# 0  Organic Social 2024-04-17 18:00:00    187       256               125
# 1  Organic Social 2024-04-17 20:00:00    175       221               112
# 2  Organic Social 2024-04-17 21:00:00    160       206               103
# 3  Organic Social 2024-05-01 19:00:00    160       219               110
# 4          Direct 2024-04-16 22:00:00    158       192                94
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            32.160156                   0.668449
# 1                            46.918552                   0.640000
# 2                            59.315534                   0.643750
# 3                            40.315068                   0.687500
# 4                            39.020833                   0.594937
#
#    Events per session  Engagement rate  Event count  Hour
# 0            4.078125         0.488281         1044    18
# 1            4.529412         0.506787         1001    20
# 2            4.694175         0.500000          967    21
# 3            4.630137         0.502283         1014    19
# 4            4.057292         0.489583          779    22

# %%
df["Bounce_Rate"] = ((df["Sessions"] - df["Engaged Sessions"]) / df["Sessions"]) * 100

# %%
df_plot = df.groupby("DateHour")[["Engagement rate", "Sessions"]].mean().reset_index()
plt.figure(figsize=(10, 5))
plt.plot(df_plot["DateHour"], df_plot["Engagement rate"], label="Engagement rate", color="green")
plt.plot(df_plot["DateHour"], df_plot["Sessions"], label="Sessions", color="blue")
plt.title(" Engagement Rate vs Sessions Over Time")
plt.xlabel("DateHour")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Bounce Rate

# %%
df[["Sessions", "Engaged Sessions", "Bounce_Rate"]].head()
# Out:
#    Sessions  Engaged Sessions  Bounce_Rate
# 0       256               125    51.171875
# 1       221               112    49.321267
# 2       206               103    50.000000
# 3       219               110    49.771689
# 4       192                94    51.041667

# %%
df["Bounce_Rate"].mean()
# Out:
# np.float64(49.659045203492106)

# %%
df.groupby("channel group")["Bounce_Rate"].mean().sort_values(ascending=False)
# Out:
# channel group
# Unassigned        99.248634
# Email             66.666667
# Direct            54.436929
# Organic Social    45.875036
# Organic Search    42.109353
# Referral          33.911798
# Organic Video     24.000000
# Name: Bounce_Rate, dtype: float64

# %%
df.columns
# Out:
# Index(['channel group', 'DateHour', 'Users', 'Sessions', 'Engaged Sessions',
#        'Average engagement time per session', 'Engaged sessions per user',
#        'Events per session', 'Engagement rate', 'Event count', 'Hour',
#        'Drop_Off', 'Bounce_Rate'],
#       dtype='object')

# %%
df.groupby("channel group")["Bounce_Rate"].mean().plot(kind="bar")
plt.title("Bounce Rate by Traffic Source")
plt.ylabel("Bounce Rate (%)")
plt.show()

# %%
df["Drop_Off"] = df["Sessions"] - df["Engaged Sessions"]

# %%
df["Conversion_Rate"] = (df["Engaged Sessions"] / df["Sessions"]) * 100

# %%
total_sessions = df["Sessions"].sum()
total_engaged = df["Engaged Sessions"].sum()

print("Sessions:", total_sessions)
print("Engaged:", total_engaged)
print("Conversion Rate:", (total_engaged/total_sessions)*100)
# Out:
# Sessions: 162095
# Engaged: 89741
# Conversion Rate: 55.363212930688796

# %%
stages = ["Sessions", "Engaged Sessions"]
values = [total_sessions, total_engaged]

plt.bar(stages, values)
plt.title("Funnel Analysis")
plt.ylabel("Users")
plt.show()
